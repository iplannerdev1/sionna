# %%
import tensorflow as tf
import pandas as pd
import os

model = tf.keras.model.Sequential(
    tf.keras.layers.Dense(64, 'tanh'),
    tf.keras.layers.Dense(128, 'tansh'),
    tf.keras.layers.Dense(1, 'sigmoid')
)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# admit, gre, gpa, rank
fpath = os.path.join('data', 'gpascore.csv')
gpascore_df = pd.read_csv(fpath)
x_rows = gpascore_df[['gre', 'gps', 'rank']].to_numpy() # .to_dict('records')
y_rows = gpascore_df[['admin']].to_numpy()

model.fit(x, y, epochs = 10)
# Out:
# 2025-02-11 04:46:34.534129: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 04:46:34.534182: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 04:46:34.536443: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 04:46:34.544816: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
